# %%
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report,roc_curve,roc_auc_score
import joblib

# %%
X_train=pd.read_csv("../New_Data/X_train.csv")
X_test=pd.read_csv("../New_Data/X_test.csv")
y_train=pd.read_csv("../New_Data/y_train.csv")
y_test=pd.read_csv("../New_Data/y_test.csv")

# %%
y_train=y_train["Churn"]
y_test=y_test["Churn"]

# %%
y_test.isnull().sum()
# Out:
# np.int64(0)

# %%
y_train.isnull().sum()
# Out:
# np.int64(0)

# %%
X_train.isnull().sum()
# Out:
# SeniorCitizen                            0
# tenure                                   0
# MonthlyCharges                           0
# TotalCharges                             0
# gender_Male                              0
# Partner_Yes                              0
# Dependents_Yes                           0
# PhoneService_Yes                         0
# MultipleLines_No phone service           0
# MultipleLines_Yes                        0
# InternetService_Fiber optic              0
# InternetService_No                       0
# OnlineSecurity_No internet service       0
# OnlineSecurity_Yes                       0
# OnlineBackup_No internet service         0
# OnlineBackup_Yes                         0
# DeviceProtection_No internet service     0
# DeviceProtection_Yes                     0
# TechSupport_No internet service          0
# TechSupport_Yes                          0
# StreamingTV_No internet service          0
# StreamingTV_Yes                          0
# ...

# %%
model=LogisticRegression(random_state=42,max_iter=10000)

# %%
model.fit(X_train,y_train.values.ravel())
# Out:
# LogisticRegression(max_iter=10000, random_state=42)

# %%
y_pred=model.predict(X_test)

# %%
acc=accuracy_score(y_test,y_pred)

# %%
pre=precision_score(y_test,y_pred)

# %%
recall=recall_score(y_test,y_pred)

# %%
f1=f1_score(y_test,y_pred)

# %%
print("Accuracy: ",acc)
print("Precision: ",pre)
print("Recall: ",recall)
print("F1_Score: ",f1)
# Out:
# Accuracy:  0.8197303051809794
# Precision:  0.683076923076923
# Recall:  0.5951742627345844
# F1_Score:  0.6361031518624641

# %%
cl_report=classification_report(y_test,y_pred)

# %%
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1036
#            1       0.68      0.60      0.64       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.75      0.76      1409
# weighted avg       0.81      0.82      0.82      1409

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
plt.figure(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.savefig("../Results/Result_Graphs/Confusion_matrix.png")
plt.show()

# %%
y_prob=model.predict_proba(X_test)[:,1]
fpr,tpr,_=roc_curve(y_test,y_prob)
plt.plot(fpr,tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.savefig("../Results/Result_Graphs/ROC_curve.png")
plt.show()
auc=roc_auc_score(y_test,y_prob)
print("ROS_AUC_SCORE: ",auc)
# Out:
# ROS_AUC_SCORE:  0.8620040473257631

# %%
with open("../Results/Metrices/Metrices.txt","w") as f:
    f.write(f"Accuracy : {acc}\n")
    f.write(f"Precision : {pre}\n")
    f.write(f"Recall : {recall}\n")
    f.write(f"F1 Score : {f1}\n")

# %%
joblib.dump(model,"../Models/Logistic_Regression.pkl")
# Out:
# ['../Models/Logistic_Regression.pkl']
